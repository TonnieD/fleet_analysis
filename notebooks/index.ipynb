# %% [markdown]
# #### Load the data 1st

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will use the **unit_id** as the primary key since it is present in all data

# %%
# Load the data
finance = pd.read_excel('../data/truck-finance.xlsx', sheet_name=1)
maintenance = pd.read_excel('../data/maintenancepo-truck.xlsx', sheet_name=1)
distance = pd.read_excel('../data/vehicle-distance-traveled.xlsx', sheet_name=1)
odometer = pd.read_excel('../data/truck-odometer-data-week-.xlsx', sheet_name=1)
stub = pd.read_excel('../data/stub-data.xlsx', sheet_name=1)
market = pd.read_excel('../data/truck-paper.xlsx', sheet_name=1)

# %%
distance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75858 entries, 0 to 75857
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               75858 non-null  int64
#  1   date             75858 non-null  datetime64[ns]
#  2   distance         75858 non-null  float64
#  3   number_of_jumps  75858 non-null  int64
#  4   start_odometer   63604 non-null  float64
#  5   end_odometer     63611 non-null  float64
#  6   tms_id           75858 non-null  int64
#  7   unit_id          75858 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(3), object(1)
# memory usage: 4.6+ MB

# %%
distance["daily_miles"] = (
    distance["end_odometer"] - distance["start_odometer"]
)

distance.loc[
    distance["start_odometer"].isna() |
    distance["end_odometer"].isna(),
    "daily_miles"
] = 0

# %%
distance['daily_miles'].head()
# Out:
# 0      0.0
# 1      0.0
# 2      0.0
# 3    430.0
# 4      0.0
# Name: daily_miles, dtype: float64

# %%
len(distance['unit_id'].unique())
# Out:
# 654
